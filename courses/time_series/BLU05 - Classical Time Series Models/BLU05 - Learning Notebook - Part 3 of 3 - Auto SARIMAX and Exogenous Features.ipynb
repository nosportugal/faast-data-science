# %% [markdown]
# # BLU05 - Learning Notebook - Part 3 of 3 - Auto SARIMAX and Exogenous Features

# %%
import itertools
import warnings
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import statsmodels.api as sm
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.linear_model import LinearRegression
from statsmodels.tsa.statespace.sarimax import SARIMAX
from statsmodels.tsa.stattools import acf
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf


import utils

# %matplotlib inline
plt.rcParams["figure.figsize"] = (16, 5)
warnings.simplefilter(action="ignore", category=FutureWarning)
warnings.filterwarnings("ignore")

# %%
airlines = utils.load_airline_data()
airlines_logged = np.log(airlines)

# %%
train = airlines_logged[:-24]
test = airlines_logged[-24:]

# %% [markdown]
# ## 1. pmdarima for auto-tuned models

# %% [markdown]
# ### 1.1 Auto SARIMAX

# %% [markdown]
# In the previous notebook we promised to show you how to get the best parameters for SARIMAX. The time has come!
#
# You may already be suspecting that the way to do it is to train several models in the train set using different parameters and choose the one with the lowest AIC (which already penalises complexity, so in theory a validation set is not needed). And you would be right! But instead of doing it manually we will use [pmdarima](http://alkaline-ml.com/pmdarima/), which is a wrapper around statsmodels for SARIMAX models which not only automatises the SARIMAX model selection but also offers some extra functionality that we will see later on.

# %%
import pmdarima as pm

# %% [markdown]
# Let's use the `AutoARIMA` function which will automatically search for the best ARIMA model based on the train set. The only thing we will tell `AutoARIMA` is that we know the seasonality is of 12 periods, by using `m=12`. We could also ask `AutoARIMA` to search for it, but it would be considerably slower.
#
# For more information on how `AutoARIMA` actually works make sure to check the [documentation](https://alkaline-ml.com/pmdarima/modules/generated/pmdarima.arima.auto_arima.html).

# %%
sarimax = pm.AutoARIMA(trace=True, supress_warnings=True, m=12)
sarimax.fit(train)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(1,1,1)[12] intercept   : AIC=-384.230, Time=1.22 sec
#  ARIMA(0,0,0)(0,1,0)[12] intercept   : AIC=-277.702, Time=0.03 sec
#  ARIMA(1,0,0)(1,1,0)[12] intercept   : AIC=-381.231, Time=0.54 sec
#  ARIMA(0,0,1)(0,1,1)[12] intercept   : AIC=-341.622, Time=0.42 sec
#  ARIMA(0,0,0)(0,1,0)[12]             : AIC=-118.985, Time=0.03 sec
#  ARIMA(2,0,2)(0,1,1)[12] intercept   : AIC=-389.776, Time=1.03 sec
#  ARIMA(2,0,2)(0,1,0)[12] intercept   : AIC=-365.957, Time=0.27 sec
#  ARIMA(2,0,2)(0,1,2)[12] intercept   : AIC=-387.768, Time=2.49 sec
#  ARIMA(2,0,2)(1,1,0)[12] intercept   : AIC=-383.803, Time=0.94 sec
#  ARIMA(2,0,2)(1,1,2)[12] intercept   : AIC=-385.833, Time=3.55 sec
#  ARIMA(1,0,2)(0,1,1)[12] intercept   : AIC=-391.119, Time=1.01 sec
#  ARIMA(1,0,2)(0,1,0)[12] intercept   : AIC=-366.329, Time=0.20 sec
#  ARIMA(1,0,2)(1,1,1)[12] intercept   : AIC=-385.543, Time=1.17 sec
#  ARIMA(1,0,2)(0,1,2)[12] intercept   : AIC=-388.834, Time=2.42 sec
#  ARIMA(1,0,2)(1,1,0)[12] intercept   : AIC=-385.183, Time=0.70 sec
#  ARIMA(1,0,2)(1,1,2)[12] intercept   : AIC=-386.992, Time=3.03 sec
#  ARIMA(0,0,2)(0,1,1)[12] intercept   : AIC=-369.722, Time=0.55 sec
#  ARIMA(1,0,1)(0,1,1)[12] intercept   : AIC=-392.903, Time=0.83 sec
#  ARIMA(1,0,1)(0,1,0)[12] intercept   : AIC=-368.179, Time=0.19 sec
#  ARIMA(1,0,1)(1,1,1)[12] intercept   : AIC=-390.911, Time=0.94 sec
#  ARIMA(1,0,1)(0,1,2)[12] intercept   : AIC=-390.962, Time=1.99 sec
#  ARIMA(1,0,1)(1,1,0)[12] intercept   : AIC=-387.096, Time=0.67 sec
#  ARIMA(1,0,1)(1,1,2)[12] intercept   : AIC=-388.936, Time=2.35 sec
#  ARIMA(1,0,0)(0,1,1)[12] intercept   : AIC=-389.787, Time=0.50 sec
#  ARIMA(2,0,1)(0,1,1)[12] intercept   : AIC=-391.872, Time=0.93 sec
#  ARIMA(0,0,0)(0,1,1)[12] intercept   : AIC=-293.600, Time=0.16 sec
#  ARIMA(2,0,0)(0,1,1)[12] intercept   : AIC=-393.537, Time=0.69 sec
#  ARIMA(2,0,0)(0,1,0)[12] intercept   : AIC=-368.885, Time=0.13 sec
#  ARIMA(2,0,0)(1,1,1)[12] intercept   : AIC=-391.335, Time=1.07 sec
#  ARIMA(2,0,0)(0,1,2)[12] intercept   : AIC=-391.560, Time=1.80 sec
#  ARIMA(2,0,0)(1,1,0)[12] intercept   : AIC=-387.544, Time=0.67 sec
#  ARIMA(2,0,0)(1,1,2)[12] intercept   : AIC=-389.765, Time=2.28 sec
#  ARIMA(3,0,0)(0,1,1)[12] intercept   : AIC=-391.764, Time=0.86 sec
#  ARIMA(3,0,1)(0,1,1)[12] intercept   : AIC=-389.870, Time=1.03 sec
#  ARIMA(2,0,0)(0,1,1)[12]             : AIC=-388.727, Time=0.51 sec
#
# Best model:  ARIMA(2,0,0)(0,1,1)[12] intercept
# Total fit time: 37.269 seconds
# AutoARIMA(m=12, trace=True)

# %% [markdown]
# Ok! So this is how we got the hyperparameters `ARIMA(2,0,0)(0,1,1)[12]`.
#
# A cool thing about `pmdarima` is that it aims to mimic `sklearn`'s API (interface). So, how do you think we can get predictions from our model? Instead of `get_forecast`, we simply use `predict`:

# %%
sarimax_forecast = sarimax.predict(24)

# %% [markdown]
# Let's also check if the MAE is the same as with `statsmodels`:

# %%
mean_absolute_error(np.exp(sarimax_forecast), np.exp(test))
# Out:
# 10.623036189768726

# %% [markdown]
# Ok, all good!

# %% [markdown]
# As we saw in the last notebook, it's interesting to validate how well our model performs for several samples by making multiple forecasts. We also saw that we can leave our model _static_, _refit_ it or completely _remake_ it. Leaving our model static is not as trivial in `pmdarima` as it is on `statsmodels`. Refitting on `pmdarima` is slightly different from `statsmodels`, because it has a method (`update`) which refits the model but using as initial parameters the ones from the old model.

# %% [markdown]
# The following loop implements multiple one-step forecasts using the `update` method from `pmdarima`. As mentioned, this is similar to refitting, but it initializes the parameters with the values from the previous fit.

# %%
sarimax_forecast_one_step_refit = []

# Note that we're fitting the AutoArima again. This is to make sure you always
# run it before the rest of the loop
sarimax.fit(train)

for i in np.arange(0, 24):
    next_step_forecast = sarimax.predict(1)[0]
    sarimax_forecast_one_step_refit.append(next_step_forecast)
    sarimax = sarimax.update(test[i : i + 1])
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(1,1,1)[12] intercept   : AIC=-384.230, Time=1.36 sec
#  ARIMA(0,0,0)(0,1,0)[12] intercept   : AIC=-277.702, Time=0.03 sec
#  ARIMA(1,0,0)(1,1,0)[12] intercept   : AIC=-381.231, Time=0.44 sec
#  ARIMA(0,0,1)(0,1,1)[12] intercept   : AIC=-341.622, Time=0.41 sec
#  ARIMA(0,0,0)(0,1,0)[12]             : AIC=-118.985, Time=0.02 sec
#  ARIMA(2,0,2)(0,1,1)[12] intercept   : AIC=-389.776, Time=1.07 sec
#  ARIMA(2,0,2)(0,1,0)[12] intercept   : AIC=-365.957, Time=0.27 sec
#  ARIMA(2,0,2)(0,1,2)[12] intercept   : AIC=-387.768, Time=2.90 sec
#  ARIMA(2,0,2)(1,1,0)[12] intercept   : AIC=-383.803, Time=0.92 sec
#  ARIMA(2,0,2)(1,1,2)[12] intercept   : AIC=-385.833, Time=3.70 sec
#  ARIMA(1,0,2)(0,1,1)[12] intercept   : AIC=-391.119, Time=1.06 sec
#  ARIMA(1,0,2)(0,1,0)[12] intercept   : AIC=-366.329, Time=0.18 sec
#  ARIMA(1,0,2)(1,1,1)[12] intercept   : AIC=-385.543, Time=1.18 sec
#  ARIMA(1,0,2)(0,1,2)[12] intercept   : AIC=-388.834, Time=2.50 sec
#  ARIMA(1,0,2)(1,1,0)[12] intercept   : AIC=-385.183, Time=0.71 sec
#  ARIMA(1,0,2)(1,1,2)[12] intercept   : AIC=-386.992, Time=2.78 sec
#  ARIMA(0,0,2)(0,1,1)[12] intercept   : AIC=-369.722, Time=0.55 sec
#  ARIMA(1,0,1)(0,1,1)[12] intercept   : AIC=-392.903, Time=0.83 sec
#  ARIMA(1,0,1)(0,1,0)[12] intercept   : AIC=-368.179, Time=0.22 sec
#  ARIMA(1,0,1)(1,1,1)[12] intercept   : AIC=-390.911, Time=0.94 sec
#  ARIMA(1,0,1)(0,1,2)[12] intercept   : AIC=-390.962, Time=1.90 sec
#  ARIMA(1,0,1)(1,1,0)[12] intercept   : AIC=-387.096, Time=0.72 sec
#  ARIMA(1,0,1)(1,1,2)[12] intercept   : AIC=-388.936, Time=2.42 sec
#  ARIMA(1,0,0)(0,1,1)[12] intercept   : AIC=-389.787, Time=0.52 sec
#  ARIMA(2,0,1)(0,1,1)[12] intercept   : AIC=-391.872, Time=0.92 sec
#  ARIMA(0,0,0)(0,1,1)[12] intercept   : AIC=-293.600, Time=0.17 sec
#  ARIMA(2,0,0)(0,1,1)[12] intercept   : AIC=-393.537, Time=0.68 sec
#  ARIMA(2,0,0)(0,1,0)[12] intercept   : AIC=-368.885, Time=0.12 sec
#  ARIMA(2,0,0)(1,1,1)[12] intercept   : AIC=-391.335, Time=1.07 sec
#  ARIMA(2,0,0)(0,1,2)[12] intercept   : AIC=-391.560, Time=1.58 sec
#  ARIMA(2,0,0)(1,1,0)[12] intercept   : AIC=-387.544, Time=0.66 sec
#  ARIMA(2,0,0)(1,1,2)[12] intercept   : AIC=-389.765, Time=2.17 sec
#  ARIMA(3,0,0)(0,1,1)[12] intercept   : AIC=-391.764, Time=0.87 sec
#  ARIMA(3,0,1)(0,1,1)[12] intercept   : AIC=-389.870, Time=1.05 sec
#  ARIMA(2,0,0)(0,1,1)[12]             : AIC=-388.727, Time=0.50 sec
#
# Best model:  ARIMA(2,0,0)(0,1,1)[12] intercept
# Total fit time: 37.474 seconds

# %% [markdown]
# Let's take a look at the MAE:

# %%
mean_absolute_error(np.exp(sarimax_forecast_one_step_refit), np.exp(test))
# Out:
# 11.096787476291276

# %% [markdown]
# You may remember that with `statsmodels` the one-step forecast refitted model obtained an MAE of 10.9%, but now we got 11.1%. The most probable reason is that initializing the parameters from the previous fit doesn't really help in this case. Remember that this is just one case, for another period or another dataset the situation can be the opposite.

# %% [markdown]
# As mentioned, instead of refitting we could also completely remake the model. This means that instead of updating the model on our `for` loop, we would fit a new auto-arima model on each step.

# %% [markdown]
# ### 1.2 Box-Cox Transformation

# %% [markdown]
# Remember in the first notebook when we mentioned that the `log` transformation is just a particular case of the Box-Cox transformation? Well, `pmdarima` makes it easy to automate Box-Cox to find the best transformation to unskew our distribution. `pmdarima` also has pipelines similar to `sklearn`, making it easy to create a pre-processing and modelling pipeline. This means all the Box-Cox transformations and inverse transformations are implicitly calculated :)

# %%
from pmdarima.pipeline import Pipeline
from pmdarima.preprocessing import BoxCoxEndogTransformer

# %%
train = airlines[:-24]
test = airlines[-24:]

# %%
sarimax_pipeline = Pipeline(
    [
        ("boxcox", BoxCoxEndogTransformer(lmbda2=1e-6)),
        ("arima", pm.AutoARIMA(trace=True, suppress_warnings=True, m=12)),
    ]
)

sarimax_pipeline.fit(train)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(1,1,1)[12] intercept   : AIC=-287.643, Time=1.24 sec
#  ARIMA(0,0,0)(0,1,0)[12] intercept   : AIC=-182.354, Time=0.02 sec
#  ARIMA(1,0,0)(1,1,0)[12] intercept   : AIC=-284.619, Time=0.40 sec
#  ARIMA(0,0,1)(0,1,1)[12] intercept   : AIC=-247.225, Time=0.21 sec
#  ARIMA(0,0,0)(0,1,0)[12]             : AIC=-21.412, Time=0.12 sec
#  ARIMA(2,0,2)(0,1,1)[12] intercept   : AIC=-291.982, Time=0.92 sec
#  ARIMA(2,0,2)(0,1,0)[12] intercept   : AIC=-270.150, Time=0.26 sec
#  ARIMA(2,0,2)(0,1,2)[12] intercept   : AIC=-290.011, Time=2.65 sec
#  ARIMA(2,0,2)(1,1,0)[12] intercept   : AIC=-286.748, Time=0.99 sec
#  ARIMA(2,0,2)(1,1,2)[12] intercept   : AIC=-288.176, Time=4.19 sec
#  ARIMA(1,0,2)(0,1,1)[12] intercept   : AIC=-293.268, Time=0.95 sec
#  ARIMA(1,0,2)(0,1,0)[12] intercept   : AIC=-270.476, Time=0.14 sec
#  ARIMA(1,0,2)(1,1,1)[12] intercept   : AIC=-290.841, Time=1.25 sec
#  ARIMA(1,0,2)(0,1,2)[12] intercept   : AIC=-291.282, Time=2.35 sec
#  ARIMA(1,0,2)(1,1,0)[12] intercept   : AIC=-288.022, Time=0.89 sec
#  ARIMA(1,0,2)(1,1,2)[12] intercept   : AIC=-289.386, Time=2.98 sec
#  ARIMA(0,0,2)(0,1,1)[12] intercept   : AIC=-274.427, Time=0.55 sec
#  ARIMA(1,0,1)(0,1,1)[12] intercept   : AIC=-294.703, Time=0.53 sec
#  ARIMA(1,0,1)(0,1,0)[12] intercept   : AIC=-272.223, Time=0.16 sec
#  ARIMA(1,0,1)(1,1,1)[12] intercept   : AIC=-292.640, Time=0.82 sec
#  ARIMA(1,0,1)(0,1,2)[12] intercept   : AIC=-292.778, Time=1.68 sec
#  ARIMA(1,0,1)(1,1,0)[12] intercept   : AIC=-289.821, Time=0.56 sec
#  ARIMA(1,0,1)(1,1,2)[12] intercept   : AIC=-291.192, Time=3.15 sec
#  ARIMA(1,0,0)(0,1,1)[12] intercept   : AIC=-292.359, Time=0.38 sec
#  ARIMA(2,0,1)(0,1,1)[12] intercept   : AIC=-293.979, Time=0.62 sec
#  ARIMA(0,0,0)(0,1,1)[12] intercept   : AIC=-200.572, Time=0.17 sec
#  ARIMA(2,0,0)(0,1,1)[12] intercept   : AIC=-295.484, Time=0.41 sec
#  ARIMA(2,0,0)(0,1,0)[12] intercept   : AIC=-273.030, Time=0.10 sec
#  ARIMA(2,0,0)(1,1,1)[12] intercept   : AIC=-293.382, Time=0.91 sec
#  ARIMA(2,0,0)(0,1,2)[12] intercept   : AIC=-293.548, Time=1.53 sec
#  ARIMA(2,0,0)(1,1,0)[12] intercept   : AIC=-290.519, Time=0.67 sec
#  ARIMA(2,0,0)(1,1,2)[12] intercept   : AIC=-291.908, Time=3.26 sec
#  ARIMA(3,0,0)(0,1,1)[12] intercept   : AIC=-293.912, Time=0.80 sec
#  ARIMA(3,0,1)(0,1,1)[12] intercept   : AIC=-292.001, Time=0.80 sec
#  ARIMA(2,0,0)(0,1,1)[12]             : AIC=-290.431, Time=0.46 sec
#
# Best model:  ARIMA(2,0,0)(0,1,1)[12] intercept
# Total fit time: 37.183 seconds
# Pipeline(steps=[('boxcox', BoxCoxEndogTransformer(lmbda2=1e-06)),
#                 ('arima', AutoARIMA(m=12, trace=True))])

# %%
mean_absolute_error(sarimax_pipeline.predict(24), test)
# Out:
# 10.135043758966466

# %% [markdown]
# Wow, that's almost a 10% improvement compared to the one with the `log` transform. Great!

# %% [markdown]
# ## 2. New Challenge!

# %% [markdown]
# You have been learning a lot, but I bet you're already tired of looking at yearly air passengers on every plot.
#
# Let's test your new skills on a new dataset - now on solar energy - and take the opportunity to mature the standard workflow.

# %%
df = pd.read_csv("data/pv.csv")
df["Datetime"] = pd.to_datetime(df["Datetime"])
df = df.set_index("Datetime")
df = df.sort_index()
train = df[df.index.to_period("M") == "2016-01"]
test = df[df.index.to_period("M") == "2016-02"]

# %% [markdown]
# First, let's take a look at the data:

# %%
train.plot()
plt.title("Solar energy production")
plt.xlabel("Time")
plt.show()

# %% [markdown]
# The data clearly seems to have some seasonality going on. On the other hand, there doesn't seem to be any significant trend. The variance also changes quite significantly, but without a clear pattern. Let's check the ACF plot to better understand the patterns going on.

# %%
plot_acf(train.dropna(), alpha=0.05, lags=80)
plt.xlabel("Lag")
plt.show()

# %% [markdown]
# From the ACF plot we can clearly see a daily (24 hours) seasonality, which makes sense given what we know about our day-night pattern (this is what we call as domain knowledge, our understanding of the problem at hand).
#
# Also note from the timeseries plot that we have values of 0, which can be problematic when taking the Box-Cox transform, so let's use `lmbda2=1` which adds a constant of 1 to the data to make it non-zero when applying the transformation.

# %%
sarimax_pipeline = Pipeline(
    [
        ("boxcox", BoxCoxEndogTransformer(lmbda2=1)),
        (
            "arima",
            pm.AutoARIMA(
                trace=True,
                suppress_warnings=True,
                m=24,
                method="nm",  # More data means longer let's use 'nm' to make it faster
                maxiter=20,  # Let's also reduce maxiter to make it faster.
            ),
        ),
    ]
)

sarimax_pipeline.fit(train)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(1,0,1)[24] intercept   : AIC=11857.366, Time=0.80 sec
#  ARIMA(0,0,0)(0,0,0)[24] intercept   : AIC=3375.167, Time=0.07 sec
#  ARIMA(1,0,0)(1,0,0)[24] intercept   : AIC=inf, Time=0.51 sec
#  ARIMA(0,0,1)(0,0,1)[24] intercept   : AIC=2222.179, Time=0.69 sec
#  ARIMA(0,0,0)(0,0,0)[24]             : AIC=3794.358, Time=0.04 sec
#  ARIMA(0,0,1)(0,0,0)[24] intercept   : AIC=2691.008, Time=0.06 sec
#  ARIMA(0,0,1)(1,0,1)[24] intercept   : AIC=3316.097, Time=0.82 sec
#  ARIMA(0,0,1)(0,0,2)[24] intercept   : AIC=2434.210, Time=1.86 sec
#  ARIMA(0,0,1)(1,0,0)[24] intercept   : AIC=2804.492, Time=0.44 sec
#  ARIMA(0,0,1)(1,0,2)[24] intercept   : AIC=3589.154, Time=2.14 sec
#  ARIMA(0,0,0)(0,0,1)[24] intercept   : AIC=2822.229, Time=0.60 sec
#  ARIMA(1,0,1)(0,0,1)[24] intercept   : AIC=1728.627, Time=0.67 sec
#  ARIMA(1,0,1)(0,0,0)[24] intercept   : AIC=2055.341, Time=0.08 sec
#  ARIMA(1,0,1)(1,0,1)[24] intercept   : AIC=2097.269, Time=0.66 sec
#  ARIMA(1,0,1)(0,0,2)[24] intercept   : AIC=1823.147, Time=4.50 sec
#  ARIMA(1,0,1)(1,0,0)[24] intercept   : AIC=1521.244, Time=0.77 sec
#  ARIMA(1,0,1)(2,0,0)[24] intercept   : AIC=2056.498, Time=2.08 sec
#  ARIMA(1,0,1)(2,0,1)[24] intercept   : AIC=2465.346, Time=1.95 sec
#  ARIMA(2,0,1)(1,0,0)[24] intercept   : AIC=2046.879, Time=0.60 sec
#  ARIMA(1,0,2)(1,0,0)[24] intercept   : AIC=1552.226, Time=0.61 sec
#  ARIMA(0,0,0)(1,0,0)[24] intercept   : AIC=inf, Time=0.46 sec
#  ARIMA(0,0,2)(1,0,0)[24] intercept   : AIC=2828.101, Time=0.50 sec
#  ARIMA(2,0,0)(1,0,0)[24] intercept   : AIC=inf, Time=0.55 sec
#  ARIMA(2,0,2)(1,0,0)[24] intercept   : AIC=1928.596, Time=0.63 sec
#  ARIMA(1,0,1)(1,0,0)[24]             : AIC=1382.159, Time=0.29 sec
#  ARIMA(1,0,1)(0,0,0)[24]             : AIC=2078.658, Time=0.06 sec
#  ARIMA(1,0,1)(2,0,0)[24]             : AIC=2082.093, Time=0.81 sec
#  ARIMA(1,0,1)(1,0,1)[24]             : AIC=2337.459, Time=1.01 sec
#  ARIMA(1,0,1)(0,0,1)[24]             : AIC=1717.165, Time=1.41 sec
#  ARIMA(1,0,1)(2,0,1)[24]             : AIC=2124.520, Time=3.73 sec
#  ARIMA(0,0,1)(1,0,0)[24]             : AIC=6.000, Time=1.30 sec
#  ARIMA(0,0,1)(0,0,0)[24]             : AIC=3683.571, Time=0.09 sec
#  ARIMA(0,0,1)(2,0,0)[24]             : AIC=3796.904, Time=4.00 sec
#  ARIMA(0,0,1)(1,0,1)[24]             : AIC=3896.328, Time=0.62 sec
#  ARIMA(0,0,1)(0,0,1)[24]             : AIC=inf, Time=0.91 sec
#  ARIMA(0,0,1)(2,0,1)[24]             : AIC=3980.903, Time=1.98 sec
#  ARIMA(0,0,0)(1,0,0)[24]             : AIC=inf, Time=0.67 sec
#  ARIMA(0,0,2)(1,0,0)[24]             : AIC=1085.529, Time=1.21 sec
#  ARIMA(1,0,0)(1,0,0)[24]             : AIC=inf, Time=2.05 sec
#  ARIMA(1,0,2)(1,0,0)[24]             : AIC=1393.096, Time=1.29 sec
#
# Best model:  ARIMA(0,0,1)(1,0,0)[24]
# Total fit time: 43.591 seconds
# Pipeline(steps=[('boxcox', BoxCoxEndogTransformer(lmbda2=1)),
#                 ('arima',
#                  AutoARIMA(m=24, maxiter=20, method='nm', trace=True))])

# %% [markdown]
# Let's look at the in-sample predictions:

# %%
plt.plot(train, label="original")
plt.plot(train.index, sarimax_pipeline.predict_in_sample(), label="sarimax forecast")
plt.xlabel("Time")
plt.title("Solar energy production")
plt.legend()
plt.show()

# %% [markdown]
# The model seems to have captured the seasonality quite well, but the changing intra-day variance not so much. Let's look at a multi-step forecast:

# %%
plt.plot(test, label="original")
plt.plot(test.index, sarimax_pipeline.predict(29 * 24), label="sarimax forecast")
plt.xlabel("Time")
plt.title("Solar energy production")
plt.legend()
plt.show()

# %% [markdown]
# The model clearly didn't capture any patterns which explain the variance changes throughout the timeseries. This probably means there's something missing on our model. Indeed, it makes sense that there is some temporal relation in solar production (the well-known daily day-night cycle), but not all days are equal right? There is something that **causes** some days to produce more power than others. Indeed, some days are sunnier (or the other way around, cloudier) than others.

# %% [markdown]
# Let's think a bit more about our problem at hand and look how we can incorporate that into our model next.

# %% [markdown]
# ### 2.2 Exogenous variables in SARIMAX

# %% [markdown]
# #### Some bits of domain knowledge

# %% [markdown]
# As you may have guessed, **solar energy production depends mainly on incoming sunlight (or solar radiation).**
#
# Thus, when forecasting solar power, the variable we really want to have is solar radiation. But note that we can't simply use solar radiation measurements contemporary to our forecast times, as this would mean that you had them before they actually happened! Are you a magician or do we need to find an alternative?
#
# Ok, so let's go with option B. Think about how you decide to take an umbrella with you when you leave your house...
# I guess that, _if you're not really a magician_, you look at the weather forecast. And what is it that weather impacts a lot? Solar radiation and it's intra-day variance! This is a quite common weather forecast variable, such as wind speed, precipitation, etc. **Since these are produced ahead of time (it is a forecast), we can use it in an operational context.**
#
#
# <img src="images/radiation_inputs.jpg" alt="Drawing" style="width: 350px;">

# %% [markdown]
# #### Exogenous and Endogenous Variables

# %% [markdown]
# When added to a forecasting model, we call an external variable such as the solar radiation forecast as an **exogenous variable**. And it is important that when you choose such variables for you model to keep in mind two things:
# - *independence* as, ideally, your exogenous input should be independent from your prediction;
# - *causality* and the mantra "_Correlation does not imply causation_".
#
# About the first point, just imagine you have a model that predicts the price of a product based on (1) demand and (2) past price values. You might be tempted to think that (1) is exogenous. But economists know that if you lower the price of a good, people will be more open to acquiring more of it. And, as such, the demand is not independent the predictions your model does, even more if you use those predictions to set the price.
#
# The second point was already discussed in the bootcamp SLU05, but if you don't remember why, check this [website](https://www.tylervigen.com/spurious-correlations). If this really piques your interest, consider this [book reading suggestion](https://www.goodreads.com/book/show/36204378-the-book-of-why).
#
# On other side of the variable spectrum, we have our solar energy production lagged values (or (2) in the price prediction example). These we call as **endogenous variables**.
#
# The definition of these concepts is not consensual, but a simplistic view is that lagged values of your target variable are **endogenous** and everything else is **exogenous**. A more complex one considers that any variable which depends on the forecast target is also **endogenous** (example for our case study: typical solar generators produce less the hotter they are, but they also get hotter the more they produce).

# %% [markdown]
# If you want to pursue further these concepts, you might want to take a look at:
# - [Endogenous](https://www.merriam-webster.com/dictionary/endogenous) and [exogenous](https://www.merriam-webster.com/dictionary/exogenous) definitions
# - this links from [Statistics How To](https://www.statisticshowto.com/endogenous-variable/), [Machine Learning Mastery](https://machinelearningmastery.com/taxonomy-of-time-series-forecasting-problems/#:~:text=An%20input%20variable%20is%20endogenous,%2D2%2C%20and%20so%20on)
# - or this economics-inspired webpage from [Reed College](https://www.reed.edu/economics/course_pages.archive/red_spots/endogenous_and_exogenous_v.htm) and [Youtube video](https://www.youtube.com/watch?v=qiQhAyuH2P4) from Free Econ Help

# %% [markdown]
# #### Enough chitchat, let's (finally) get our hands dirty with SARIMAX

# %% [markdown]
# Let's load a radiation forecast dataset. Note that the index of this dataset doesn't correspond to the measure date, it corresponds to the forecasts date. And all these forecasts were made the month before, so this means we can use them for next month's forecasts.

# %%
exog = pd.read_csv("data/radiation.csv")
exog.Datetime = pd.to_datetime(exog.Datetime)
exog = exog.set_index("Datetime")
exog = exog.sort_index()
exog_train = exog["2016-01-01 07":"2016-01-31"]
exog_test = exog[exog.index.to_period("M") == "2016-02"]

# %%
sarimax_pipeline_exog = Pipeline(
    [  # The Box-Cox transform has been removed because it messes with the exogenous input
        (
            "arima",
            pm.AutoARIMA(
                trace=True,
                suppress_warnings=True,
                m=24,
                method="nm",
                maxiter=20,
            ),
        )
    ]
)

sarimax_pipeline_exog.fit(train, exog_train)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(1,0,1)[24] intercept   : AIC=11007.871, Time=0.96 sec
#  ARIMA(0,0,0)(0,0,0)[24] intercept   : AIC=11554.604, Time=0.06 sec
#  ARIMA(1,0,0)(1,0,0)[24] intercept   : AIC=11008.410, Time=0.48 sec
#  ARIMA(0,0,1)(0,0,1)[24] intercept   : AIC=11163.427, Time=0.54 sec
#  ARIMA(0,0,0)(0,0,0)[24]             : AIC=11682.096, Time=0.07 sec
#  ARIMA(2,0,2)(0,0,1)[24] intercept   : AIC=11005.715, Time=0.63 sec
#  ARIMA(2,0,2)(0,0,0)[24] intercept   : AIC=11017.336, Time=0.08 sec
#  ARIMA(2,0,2)(0,0,2)[24] intercept   : AIC=11009.762, Time=2.49 sec
#  ARIMA(2,0,2)(1,0,0)[24] intercept   : AIC=11004.824, Time=0.70 sec
#  ARIMA(2,0,2)(2,0,0)[24] intercept   : AIC=11013.516, Time=2.73 sec
#  ARIMA(2,0,2)(2,0,1)[24] intercept   : AIC=11013.318, Time=2.43 sec
#  ARIMA(1,0,2)(1,0,0)[24] intercept   : AIC=11003.543, Time=0.64 sec
#  ARIMA(1,0,2)(0,0,0)[24] intercept   : AIC=11016.060, Time=0.10 sec
#  ARIMA(1,0,2)(2,0,0)[24] intercept   : AIC=11012.659, Time=1.88 sec
#  ARIMA(1,0,2)(1,0,1)[24] intercept   : AIC=11006.608, Time=0.78 sec
#  ARIMA(1,0,2)(0,0,1)[24] intercept   : AIC=11004.477, Time=0.78 sec
#  ARIMA(1,0,2)(2,0,1)[24] intercept   : AIC=11012.427, Time=2.32 sec
#  ARIMA(0,0,2)(1,0,0)[24] intercept   : AIC=11062.400, Time=0.60 sec
#  ARIMA(1,0,1)(1,0,0)[24] intercept   : AIC=11001.523, Time=0.63 sec
#  ARIMA(1,0,1)(0,0,0)[24] intercept   : AIC=11014.126, Time=0.07 sec
#  ARIMA(1,0,1)(2,0,0)[24] intercept   : AIC=11010.445, Time=2.04 sec
#  ARIMA(1,0,1)(1,0,1)[24] intercept   : AIC=11003.718, Time=0.73 sec
#  ARIMA(1,0,1)(0,0,1)[24] intercept   : AIC=11002.638, Time=0.71 sec
#  ARIMA(1,0,1)(2,0,1)[24] intercept   : AIC=11010.150, Time=2.11 sec
#  ARIMA(0,0,1)(1,0,0)[24] intercept   : AIC=11162.879, Time=0.48 sec
#  ARIMA(2,0,1)(1,0,0)[24] intercept   : AIC=11004.727, Time=0.64 sec
#  ARIMA(0,0,0)(1,0,0)[24] intercept   : AIC=11548.992, Time=0.47 sec
#  ARIMA(2,0,0)(1,0,0)[24] intercept   : AIC=11001.558, Time=0.62 sec
#  ARIMA(1,0,1)(1,0,0)[24]             : AIC=11005.252, Time=1.03 sec
#
# Best model:  ARIMA(1,0,1)(1,0,0)[24] intercept
# Total fit time: 27.855 seconds
# Pipeline(steps=[('arima',
#                  AutoARIMA(m=24, maxiter=20, method='nm', trace=True))])

# %% [markdown]
# Let's look at the in-sample predictions:

# %%
plt.plot(train, label="original")
plt.plot(
    train.index,
    sarimax_pipeline_exog.predict_in_sample(exog_train),
    label="sarimax_exog forecast",
)
plt.xlabel("Time")
plt.title("Solar energy production")
plt.legend()
plt.show()

# %% [markdown]
# It captured the variance changes much better! What about the multi-step forecast?

# %%
plt.plot(test, label="original")
plt.plot(
    test.index,
    sarimax_pipeline_exog.predict(29 * 24, exog_test),
    label="sarimax_exog forecast",
)
plt.xlabel("Time")
plt.title("Solar energy production")
plt.legend()
plt.show()

# %% [markdown]
# Looking good! This is a context where the use of exogenous variables clearly improves performance. But there are many other cases such as this one. For example, to forecast supermarket sales it might be relevant to take into account temperature forecasts; to forecast wind power we need to take into account wind forecasts, etc.

# %% [markdown]
# ## 3. Confidence Intervals

# %% [markdown]
# Also, have we told you that you can also get confidence intervals for free? Simply use `return_conf_int=True`:

# %%
preds = sarimax_pipeline_exog.predict(24 * 7, exog_test[: 24 * 7], return_conf_int=True)

# %%
def plot_predictions(series_, pred_):

    mean_predictions_ = pd.Series(pred_[0], index=series_.index)

    pred_ci_ = pd.DataFrame(
        pred_[1], columns=["lower bound", "upper bound"], index=series_.index
    )

    series_.plot(label="observed")
    mean_predictions_.plot(label="predicted", alpha=0.7)

    plt.fill_between(
        pred_ci_.index,
        pred_ci_["lower bound"],
        pred_ci_["upper bound"],
        color="k",
        alpha=0.2,
    )

    plt.xlabel("Time")
    plt.title("Solar energy production")
    plt.legend()
    plt.show()

# %%
plot_predictions(test["2016-02-01":"2016-02-07"], preds)

# %% [markdown]
# Confidence intervals can be very useful for business-driven decisions. In most real scenarios we're not only interested in the forecasted value but also in the uncertainty associated to it.
#
# Note that we've been talking mostly about timeseries forecasting, but there are many other machine learning applications related to timeseries: timeseries classification; anomaly detection; change point detection, etc.
#
# Confidence intervals are particularly important for anomaly detection. You can imagine that when we have real values that fall considerably out of our forecast bounds then we may have some abnormal behavior. For a quick intro to some of the concepts in timeseries anomaly detection check out this [article](https://docs.microsoft.com/en-us/azure/machine-learning/studio-module-reference/time-series-anomaly-detection).
#
# Also, here we looked quite a lot into SARIMAX models, but there are several other timeseries models and tools. One that deserves special mention is facebook's [Prophet](https://facebook.github.io/prophet/).
